# %%
from datasets import load_dataset
from sklearn.model_selection import train_test_split

# %%
ds = load_dataset("wangrongsheng/ag_news")
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 120000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 7600
#     })
# })

# %%
train_df = ds["train"].to_pandas().sample(n=800, random_state=42)
test_df = ds["test"].to_pandas().sample(n=200, random_state=42)

# %%
val_df,test_df = train_test_split(test_df, test_size=0.5, random_state=42)

# %%
train_df = train_df.rename(columns={'text': 'sentence'})
val_df = val_df.rename(columns={'text': 'sentence'})
test_df = test_df.rename(columns={'text': 'sentence'})

# %%
train_df.to_csv("train.csv", index=False, encoding="utf-8")
val_df.to_csv("val.csv", index=False, encoding="utf-8")
test_df.to_csv("test.csv", index=False, encoding="utf-8")

# %%
len(train_df)
# Out:
# 800

# %%
len(val_df)
# Out:
# 100

# %%
len(test_df)
# Out:
# 100
